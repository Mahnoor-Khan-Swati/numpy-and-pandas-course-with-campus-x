# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3487865751.py in <cell line: 0>()
# ----> 1 uploaded=files.upload()
#
# NameError: name 'files' is not defined

# %% [markdown]
# **Company wale data ke sirf shuru ke 2 records (satarain) mujhe dikha do.**

# %%
company=pd.read_csv('Fortune.csv')
company.head(2)
# Out:
#    company  rank  rank_change   revenue   profit  num. of employees  \
# 0  Walmart     1          0.0  572754.0  13673.0          2300000.0
# 1   Amazon     2          0.0  469822.0  33364.0          1608000.0
#
#       sector         city state newcomer ceo_founder ceo_woman profitable  \
# 0  Retailing  Bentonville    AR       no          no        no        yes
# 1  Retailing      Seattle    WA       no          no        no        yes
#
#   prev_rank                  CEO                        Website Ticker  \
# 0       1.0  C. Douglas McMillon  https://www.stock.walmart.com    WMT
# 1       2.0      Andrew R. Jassy                 www.amazon.com   AMZN
#
#   Market Cap
# 0     352037
# 1    1202717

# %% [markdown]
# # create group by object

# %% [markdown]
# **"Har sector (jaise Technology, Healthcare, Finance, etc.) ke andar jitni companies hain, unko aik group bana do."**

# %%
company.groupby('sector')#Har sector ke mutabiq companies ko alag alag groups mein divide karo

# %% [markdown]
# **os group by object ka andar secter kitna ha**

# %%
len(company)
# Out:
# 1000

# %%
sectors=company.groupby('sector')

# %%
sectors

# %%
len(sectors)
# Out:
# 21

# %%
sectors.size()#Har group (sector) mein kitni rows (entries) hain, yeh count karo
# Out:
# sector
# Aerospace & Defense               17
# Apparel                           16
# Business Services                 52
# Chemicals                         29
# Energy                           100
# Engineering & Construction        32
# Financials                       166
# Food & Drug Stores                 9
# Food, Beverages & Tobacco         34
# Health Care                       77
# Hotels, Restaurants & Leisure     28
# Household Products                23
# Industrials                       50
# Materials                         46
# Media                             28
# Motor Vehicles & Parts            20
# Retailing                         77
# Technology                       121
# Telecommunications                 9
# Transportation                    35
# Wholesalers                       31
# dtype: int64

# %% [markdown]
# **📌 Example:
#
# Agar aap ke paas ye data hai:
#
# name	sector
# A	IT
# B	Finance
# C	IT
# D	Health
# E	IT
# F	Health
#
# sector
# IT        3
# Health    2
# Finance   1**

# %%
sectors.size().sort_values(ascending=false)#List ko aise arrange karo ke jo sector sabse zyada baar aata hai, wo top pe ho.

# %% [markdown]
# **ascending=False ka matlab hota hai:
#
# "Chhoti se badi nahin, balkay badi se chhoti value wali sorting karo.**

# %%
sectors.first()
# Out:
#                                                 company  rank  rank_change  \
# sector
# Aerospace & Defense                     Lockheed Martin    55         -6.0
# Apparel                                            Nike    83          2.0
# Business Services                                PayPal   143         -9.0
# Chemicals                                           Dow    64         18.0
# Energy                                      Exxon Mobil     6          4.0
# Engineering & Construction                  D.R. Horton   124         24.0
# Financials                           Berkshire Hathaway     7         -1.0
# Food & Drug Stores             Walgreens Boots Alliance    18         -2.0
# Food, Beverages & Tobacco        Archer Daniels Midland    38         13.0
# Health Care                                  CVS Health     4          0.0
# Hotels, Restaurants & Leisure                 Starbucks   120          5.0
# ...

# %%
sectors.last()
# Out:
#                                                 company  rank  rank_change  \
# sector
# Aerospace & Defense                    BWX Technologies   995          0.0
# Apparel                                           Crocs   954          0.0
# Business Services                                Harsco   991          0.0
# Chemicals                                       Ashland   999          0.0
# Energy                                   Genesis Energy   994          0.0
# Engineering & Construction             Beazer Homes USA   992          0.0
# Financials                                        Cowen   998          0.0
# Food & Drug Stores               Grocery Outlet Holding   816          0.0
# Food, Beverages & Tobacco                  Brown-Forman   759          0.0
# Health Care                                      Chemed   993          0.0
# Hotels, Restaurants & Leisure         Acushnet Holdings   990          0.0
# ...

# %%
sectors.groups#hHar sector ke andar kaunsi rows (indexes) hain, yeh dikhao
company.iloc[23,:]#iloc ka matlab hai: index-location, 23 row and sara colum
# Out:
# company                     JPMorgan Chase
# rank                                    24
# rank_change                           -5.0
# revenue                           127202.0
# profit                             48334.0
# num. of employees                 271025.0
# sector                          Financials
# city                              New York
# state                                   NY
# newcomer                                no
# ceo_founder                             no
# ceo_woman                               no
# profitable                             yes
# prev_rank                             19.0
# CEO                            James Dimon
# Website              www.jpmorganchase.com
# Ticker                                 JPM
# Market Cap                          336469
# Name: 23, dtype: object

# %%
sectors.get_group('Apparel')#pora group ma se 1 group chay ya use kara ga
# Out:
#                   company  rank  rank_change  revenue  profit  \
# 82                   Nike    83          2.0  44538.0  5727.0
# 379              VF Corp.   380       -117.0   9238.8   407.9
# 384                   PVH   385         19.0   9154.7   952.3
# 457           Hanesbrands   458        -26.0   7347.8    77.2
# 505       Skechers U.S.A.   506          0.0   6310.2   741.5
# 539          Levi Strauss   540          0.0   5763.9   553.5
# 540              Tapestry   541          0.0   5746.3   834.2
# 545          Under Armour   546          0.0   5683.5   360.1
# 657          Ralph Lauren   658          0.0   4400.8  -121.1
# 753              Carter's   754          0.0   3486.4   339.7
# 812   Columbia Sportswear   813          0.0   3126.4   354.1
# 884   G-III Apparel Group   885          0.0   2766.5   200.6
# 917       Deckers Outdoor   918          0.0   2545.6   382.6
# 922        Kontoor Brands   923          0.0   2475.9   195.4
# ...

# %%
sectors.sum()#numerical colunm pr sum apply ho jay ga
# Out:
#                                                                          company  \
# sector
# Aerospace & Defense            Lockheed MartinRaytheon TechnologiesBoeingGene...
# Apparel                        NikeVF Corp.PVHHanesbrandsSkechers U.S.A.Levi ...
# Business Services              PayPalVisaManpowerGroupMastercardWaste Managem...
# Chemicals                      Dow3MSherwin-WilliamsDuPontPPG IndustriesEcola...
# Energy                         Exxon MobilChevronMarathon PetroleumPhillips 6...
# Engineering & Construction     D.R. HortonLennarFluorAECOMJacobs Engineering ...
# Financials                     Berkshire HathawayJPMorgan ChaseFannie MaeBank...
# Food & Drug Stores             Walgreens Boots AllianceKrogerAlbertsonsPublix...
# Food, Beverages & Tobacco      Archer Daniels MidlandPepsiCoTyson FoodsCoca-C...
# Health Care                    CVS HealthUnitedHealth GroupMcKessonAmerisourc...
# ...

# %%
sectors = company.groupby('sector')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3924309736.py in <cell line: 0>()
# ----> 1 sectors = company.groupby('sector')
#       2
#
# NameError: name 'company' is not defined

# %%
sectors.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1256363577.py in <cell line: 0>()
# ----> 1 sectors.mean()
#
# NameError: name 'sectors' is not defined

# %%
sectors.['Revenues'].mean().sort_values(ascending=False)
# Out:
#   File "/tmp/ipython-input-3043714723.py", line 1
#     sectors.['Revenues'].mean().sort_values(ascending=False)
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # lecture 12 group on iol data set

# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f10748fd-8e8f-43ef-adfd-54014a6bd1d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f10748fd-8e8f-43ef-adfd-54014a6bd1d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
delivery.head(2)

# %%
delivery.groupby('batsman')#coulm wo jis ka griupb by karna ha wo ha batsman

# %%
runs.get('v koli')#get se particular ggroup nikala ga and run ma store kara ga

# %%
run['batsman_runs'].sum().sort_values(ascending=False).head

# %% [markdown]
# **jis na sab se ziada choka mara**

# %%
mask=delivery['battsman_run']==4 #wo row chya jaha batsmna ka run ki value ha 4
new_delivery=delivery[mask]#true false wala laga ga

# %% [markdown]
# **aj tak ipl ma kitna choka laga**

# %%
new_delivery.shape(0)

# %% [markdown]
# chaka kitna laga aj tak ip; ma tu ham oper line ma 4 ki jaga 6 dala ga

# %% [markdown]
# **sab se ziada chaka kis na mara ha**

# %%
new_delivery.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False)
#sum ki jaga count kara ga
#top 5 chya tu .count wala line lika

# %% [markdown]
# #sab se pehla wohi rows chya jis ma batsman v koli ha
# #pir group by team kara ga
# #pir batsmn k aoper sum kara ga

# %%
vk=delivery[delivery]['batsman']=='v koli']

# %%
vk.groupby('bowling_team')['batsman_run'].sum().sort_values(ascending=False).head(3)

# %% [markdown]
# **asa function banay jis ka string ka formate ma name lika os ka score batay**

# %%
def run_scored(batsman_name):
  vk=delivery[delivery['batsman']==batsman_name]
  return vk.groupby('bowling_team')['batsman_run'].sum().sort_values(ascending=False).head(3)

# %%
run_scored('v koli')

# %% [markdown]
# # lecture 13 the isin()function

# %% [markdown]
# **top 5 bateman in term of run score**

# %% [markdown]
# # isin()
# #find the most desturctive death over batsman in the history of ipl
# #strike rate=(number of balls/100
# #minimum batsman 200 balls in over 16-20

# %%
delivery[delivery['over']>15]

# %%
deathsover.groupby ('batsman')['batsman_runs'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-577777663.py in <cell line: 0>()
# ----> 1 delivery.head(2)
#
# NameError: name 'delivery' is not defined

# %%
all_batsman=death_over.groupby('batsman')['batsman_runs'].count()
x=all_batsman>200
batsman_list=all_batsman[x].index.tolist()

# %% [markdown]
# **run scored by all thses 43 batsman**
#
#
# **balls played by these 43 batsman**

# %%
final=delivery[delivery['bastman'].isin(batsman_list).shape

# %% [markdown]
# **runs calculate kara ga**

# %%
runs=batsman('bastman')['batsman_runs'].sum()

# %%
balls=batsman('bastman')['batsman_runs'].sum().count()

# %%
sr(runs/balls)*100

# %%
sr

# %% [markdown]
# # Lecture 14 (The merge function)

# %%
match

# %%
new=delivery.merge(match,left_on='match_id',right_on='id').shape

# %%
print(delivery.shape)
print(match.shape)

# %%
new.groupby(['season','batsman')['batsman_runs'].sum().rest_index()

# %%
new.groupby(['season','batsman')['batsman_runs'].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset='season',keep='first').sort_values('season')
